# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
# entire raw enrichment result

df0 = pd.read_csv("4_clusters_brain/0.xls", sep='\t')
df1 = pd.read_csv("4_clusters_brain/1.xls", sep='\t')
df2 = pd.read_csv("4_clusters_brain/2.xls", sep='\t')
df3 = pd.read_csv("4_clusters_brain/3.xls", sep='\t')

# %%
df0 = df0[df0['FDR q-value']<0.05]
df1 = df1[df1['FDR q-value']<0.05]
df2 = df2[df2['FDR q-value']<0.05]
df3 = df3[df3['FDR q-value']<0.05]

# %%
print(df2)
# Out:
#        GO Term                                        Description  \
# 0   GO:0023052                                          signaling
# 1   GO:0099536                                 synaptic signaling
# 2   GO:0099537                           trans-synaptic signaling
# 3   GO:0098916               anterograde trans-synaptic signaling
# 4   GO:0007268                     chemical synaptic transmission
# ..         ...                                                ...
# 64  GO:0050906  detection of stimulus involved in sensory perc...
# 65  GO:0007600                                 sensory perception
# 66  GO:0017157                           regulation of exocytosis
# 67  GO:0051234                      establishment of localization
# 68  GO:0050808                               synapse organization
#
#          P-value   FDR q-value  Enrichment    N    B    n    b  \
# 0   8.050000e-16  5.370000e-12        1.92  739   85  321   71
# 1   5.030000e-15  1.670000e-11        2.02  739   66  321   58
# 2   5.030000e-15  1.120000e-11        2.02  739   66  321   58
# 3   1.160000e-14  1.940000e-11        2.04  739   62  321   55
# 4   1.160000e-14  1.550000e-11        2.04  739   62  321   55
# ..           ...           ...         ...  ...  ...  ...  ...
# 64  2.210000e-04  2.260000e-02        2.30  739   10  321   10
# 65  3.910000e-04  3.940000e-02        1.64  739   38  321   27
# 66  4.420000e-04  4.400000e-02        1.77  739   26  321   20
# 67  4.480000e-04  4.390000e-02        1.21  739  234  321  123
# 68  5.120000e-04  4.940000e-02        1.59  739   42  321   29
#
#                                                 Genes
# 0   [SYN1  -  synapsin i, PARK2  -  parkinson prot...
# 1   [SYN1  -  synapsin i, PARK2  -  parkinson prot...
# 2   [SYN1  -  synapsin i, PARK2  -  parkinson prot...
# 3   [SYN1  -  synapsin i, PARK2  -  parkinson prot...
# 4   [SYN1  -  synapsin i, PARK2  -  parkinson prot...
# ..                                                ...
# 64  [OR52M1  -  olfactory receptor, family 52, sub...
# 65  [OR2M4  -  olfactory receptor, family 2, subfa...
# 66  [SYN1  -  synapsin i, GRIK5  -  glutamate rece...
# 67  [PARK2  -  parkinson protein 2, e3 ubiquitin p...
# 68  [SYN1  -  synapsin i, CHRNA7  -  cholinergic r...
#
# [69 rows x 10 columns]

# %%
# gene list / gene description column

gl0 = df0["Genes"].tolist()
gl1 = df1["Genes"].tolist()
gl2 = df2["Genes"].tolist()
gl3 = df3["Genes"].tolist()

# %%
print(gl2)
# Out:
# ['[SYN1  -  synapsin i, PARK2  -  parkinson protein 2, e3 ubiquitin protein ligase (parkin), SYN2  -  synapsin ii, CTNNA3  -  catenin (cadherin-associated protein), alpha 3, CHRNA7  -  cholinergic receptor, nicotinic, alpha 7 (neuronal), DRD2  -  dopamine receptor d2, DRD3  -  dopamine receptor d3, CHRNB3  -  cholinergic receptor, nicotinic, beta 3 (neuronal), NLGN2  -  neuroligin 2, CHRM3  -  cholinergic receptor, muscarinic 3, KCNQ2  -  potassium voltage-gated channel, kqt-like subfamily, member 2, KCNQ3  -  potassium voltage-gated channel, kqt-like subfamily, member 3, DRD1  -  dopamine receptor d1, NLGN1  -  neuroligin 1, APBA2  -  amyloid beta (a4) precursor protein-binding, family a, member 2, RIT2  -  ras-like without caax 2, PLN  -  phospholamban, CACNA2D1  -  calcium channel, voltage-dependent, alpha 2/delta subunit 1, WNT1  -  wingless-type mmtv integration site family, member 1, CACNB2  -  calcium channel, voltage-dependent, beta 2 subunit, CACNA2D3  -  calcium channel, voltage-dependent, alpha 2/delta subunit 3, CACNA1F  -  calcium channel, voltage-dependent, l type, alpha 1f subunit, CACNA1E  -  calcium channel, voltage-dependent, r type, alpha 1e subunit, GABRA4  -  gamma-aminobutyric acid (gaba) a receptor, alpha 4, DLGAP2  -  discs, large (drosophila) homolog-associated protein 2, DLGAP1  -  discs, large (drosophila) homolog-associated protein 1, GABBR2  -  gamma-aminobutyric acid (gaba) b receptor, 2, CX3CR1  -  chemokine (c-x3-c motif) receptor 1, HTR3C  -  5-hydroxytryptamine (serotonin) receptor 3c, ionotropic, SLC6A1  -  solute carrier family 6 (neurotransmitter transporter), member 1, NLGN3  -  neuroligin 3, CNTNAP2  -  contactin associated protein-like 2, NLGN4Y  -  neuroligin 4, y-linked, DAGLA  -  diacylglycerol lipase, alpha, SLITRK5  -  slit and ntrk-like family, member 5, GLRA2  -  glycine receptor, alpha 2, SLC12A5  -  solute carrier family 12 (potassium/chloride transporter), member 5, NRXN1  -  neurexin 1, HTR3A  -  5-hydroxytryptamine (serotonin) receptor 3a, ionotropic, ESR2  -  estrogen receptor 2 (er beta), NRXN2  -  neurexin 2, SNAP25  -  synaptosomal-associated protein, 25kda, GABRG3  -  gamma-aminobutyric acid (gaba) a receptor, gamma 3, GABRB3  -  gamma-aminobutyric acid (gaba) a receptor, beta 3, HTR1B  -  5-hydroxytryptamine (serotonin) receptor 1b, g protein-coupled, GRID2  -  glutamate receptor, ionotropic, delta 2, GRID1  -  glutamate receptor, ionotropic, delta 1, CNR1  -  cannabinoid receptor 1 (brain), UNC13A  -  unc-13 homolog a (c. elegans), CACNA1D  -  calcium channel, voltage-dependent, l type, alpha 1d subunit, GRIA1  -  glutamate receptor, ionotropic, ampa 1, CACNA1B  -  calcium channel, voltage-dependent, n type, alpha 1b subunit, GRIK5  -  glutamate receptor, ionotropic, kainate 5, GRIN1  -  glutamate receptor, ionotropic, n-methyl d-aspartate 1, GRIN2A  -  glutamate receptor, ionotropic, n-methyl d-aspartate 2a, GRIN2B  -  glutamate receptor, ionotropic, n-methyl d-aspartate 2b, GRIK2  -  glutamate receptor, ionotropic, kainate 2, GRIK3  -  glutamate receptor, ionotropic, kainate 3, GRIK4  -  glutamate receptor, ionotropic, kainate 4, NLGN4X  -  neuroligin 4, x-linked, CACNA1G  -  calcium channel, voltage-dependent, t type, alpha 1g subunit, GRM7  -  glutamate receptor, metabotropic 7, KCND2  -  potassium voltage-gated channel, shal-related subfamily, member 2, KCND3  -  potassium voltage-gated channel, shal-related subfamily, member 3, ADORA2A  -  adenosine a2a receptor, CDH8  -  cadherin 8, type 2, PTCHD1  -  patched domain containing 1, GRM5  -  glutamate receptor, metabotropic 5, DLGAP3  -  discs, large (drosophila) homolog-associated protein 3, IL1RAPL1  -  interleukin 1 receptor accessory protein-like 1, ANK2  -  ankyrin 2, neuronal]', '[SYN1  -  synapsin i, PARK2  -  parkinson protein 2, e3 ubiquitin protein ligase (parkin), SYN2  -  synapsin ii, CHRNA7  -  cholinergic receptor, nicotinic, alpha 7 (neuronal), DRD2  -  dopamine receptor d2, DRD3  -  dopamine recepto ...

# %%
df_list = [df0, df1, df2, df3]

gene_list = [gl0, gl1, gl2, gl3]

# %%
# number of genes in the enrichment GO terms

# iterate throuch each cell in the contingency table 
for enriched_cell in gene_list:
    
    # list to store extracted genes that belong to enriched GO terms
    enriched_genes = []
    
    # in a cell, iterate through enriched GO terms
    for go_term in enriched_cell:
        
        # need to remove confusing enclosing brackets from string 
        unparsed_string = go_term[1:-1]
        
        # then transform it into a list of unparsed gene + description strings
        unprocessed_list = unparsed_string.split('  -  ')
        
        # the first one can be added right away
        enriched_genes.append(unprocessed_list[0])
        
        # iterate through the list. last element ignored (it only contains a description)
        for gene_description in unprocessed_list[1:-1]:
            
            # the last word of the description contains a gene id (that belongs to the next description..)
            gene_id = gene_description.rsplit(' ', 1)[-1]
            enriched_genes.append(gene_id)
    
    print(len(set(enriched_genes)))
# Out:
# 11
# 190
# 250
# 0

# %%
# geometric average of p-values in GO terms enriched

# iterate throuch each cell in the contingency table 
for enriched_cell in df_list:
    print(np.round(np.mean(enriched_cell["FDR q-value"].tolist()), 8))

# %%
#for enriched_cell in df_list:
#    print(np.round(np.max(enriched_cell["FDR q-value"].tolist()), 8))

# %%
for enriched_cell in df_list:
    print(np.round(-1 * np.log10(np.median(enriched_cell["FDR q-value"].tolist())), 8))
# Out:
# 1.63078414
# 2.94692156
# 3.4621809
# nan

# %%
for enriched_cell in df_list:
    print(np.round(np.min(enriched_cell["FDR q-value"].tolist()), 8))

# %%
for enriched_cell in df_list:
    print(len(enriched_cell))
# Out:
# 3
# 147
# 69
# 0
