# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
# this is just to double check the amount of genes 

d0 = pd.read_csv("lung_gorilla/0.csv", sep='\t')
d1 = pd.read_csv("lung_gorilla/1.csv", sep='\t')
d2 = pd.read_csv("lung_gorilla/2.csv", sep='\t')
d3 = pd.read_csv("lung_gorilla/3.csv", sep='\t')
d4 = pd.read_csv("lung_gorilla/4.csv", sep='\t')

print(d0.shape)
print(d1.shape)
print(d2.shape)
print(d3.shape)
print(d4.shape)
# Out:
# (75, 3)
# (175, 3)
# (206, 3)
# (115, 3)
# (113, 3)

# %%
# entire raw enrichment result

df0 = pd.read_csv("lung_gorilla/0.xls", sep='\t')
df1 = pd.read_csv("lung_gorilla/1.xls", sep='\t')
df2 = pd.read_csv("lung_gorilla/2.xls", sep='\t')
df3 = pd.read_csv("lung_gorilla/3.xls", sep='\t')
df4 = pd.read_csv("lung_gorilla/4.xls", sep='\t')

# %%
print(df2)
# Out:
#        GO Term                                        Description  \
# 0   GO:0099536                                 synaptic signaling
# 1   GO:0099537                           trans-synaptic signaling
# 2   GO:0098916               anterograde trans-synaptic signaling
# 3   GO:0007268                     chemical synaptic transmission
# 4   GO:0098742  cell-cell adhesion via plasma-membrane adhesio...
# 5   GO:0007267                                cell-cell signaling
# 6   GO:0023052                                          signaling
# 7   GO:0007156  homophilic cell adhesion via plasma membrane a...
# 8   GO:0042391                   regulation of membrane potential
# 9   GO:0007154                                 cell communication
# 10  GO:0098609                                 cell-cell adhesion
# 11  GO:0022610                                biological adhesion
# 12  GO:0007155                                      cell adhesion
# 13  GO:0003008                                     system process
# 14  GO:0034220                        ion transmembrane transport
# 15  GO:0050877                             nervous system process
# 16  GO:0050804       modulation of chemical synaptic transmission
# 17  GO:0055085                            transmembrane transport
# 18  GO:0099177             regulation of trans-synaptic signaling
# 19  GO:0043269                        regulation of ion transport
# 20  GO:0006811                                      ion transport
# 21  GO:0060078      regulation of postsynaptic membrane potential
# 22  GO:0007399                         nervous system development
# 23  GO:0098660              inorganic ion transmembrane transport
# 24  GO:0007186       G protein-coupled receptor signaling pathway
# 25  GO:0006812                                   cation transport
# 26  GO:0098655                     cation transmembrane transport
# 27  GO:0030001                                metal ion transport
# 28  GO:0007600                                 sensory perception
# 29  GO:0098662           inorganic cation transmembrane transport
# 30  GO:0048731                                 system development
# 31  GO:0035249               synaptic transmission, glutamatergic
# 32  GO:0050906  detection of stimulus involved in sensory perc...
#
#          P-value  FDR q-value  Enrichment    N    B    n   b  \
# 0   1.050000e-09     0.000007        2.29  679   54  203  37
# 1   1.050000e-09     0.000003        2.29  679   54  203  37
# 2   3.050000e-09     0.000007        2.30  679   51  203  35
# 3   3.050000e-09     0.000005        2.30  679   51  203  35
# 4   4.360000e-09     0.000006        2.49  679   39  203  29
# 5   1.880000e-08     0.000020        2.12  679   60  203  38
# 6   3.040000e-08     0.000028        2.01  679   70  203  42
# 7   8.300000e-08     0.000068        2.56  679   30  203  23
# 8   1.330000e-07     0.000096        2.02  679   63  203  38
# 9   1.730000e-06     0.001130        1.83  679   75  203  41
# 10  2.730000e-06     0.001620        1.88  679   66  203  37
# 11  3.200000e-06     0.001740        1.69  679   97  203  49
# 12  3.200000e-06     0.001600        1.69  679   97  203  49
# 13  3.670000e-06     0.001710        1.67  679  100  203  50
# 14  9.170000e-06     0.003980        1.79  679   71  203  38
# 15  1.060000e-05     0.004320        1.74  679   79  203  41
# 16  1.440000e-05     0.005500        1.77  679   72  203  38
# 17  2.060000e-05     0.007460        1.72  679   78  203  40
# 18  2.210000e-05     0.007580        1.74  679   73  203  38
# 19  2.820000e-05     0.009170        1.74  679   71  203  37
# 20  3.190000e-05     0.009890        1.65  679   87  203  43
# 21  8.220000e-05     0.024300        2.46  679   19  203  14
# 22  1.090000e-04     0.031000        1.90  679   44  203  25
# 23  1.450000e-04     0.039400        1.85  679   47  203  26
# 24  1.660000e-04     0.043300        1.92  679   40  203  23
# 25  1.840000e-04     0.046100        1.76  679   55  203  29
# 26  2.330000e-04     0.056200        1.81  679   48  203  26
# 27  2.910000e-04     0.067600        1.82  679   46  203  25
# 28  4.480000e-04     0.101000        2.01  679   30  203  18
# 29  4.510000e-04     0.098000        1.83  679   42  203  23
# 30  4.950000e-04     0.104000        1.58  679   76  203  36
# 31  5.060000e-04     0.103000        2.74  679   11  203   9
# 32  6.780000e-04     0.134000        3.34  679    6  203   6
#
#                                                 Genes
# 0   [SYN1  -  synapsin i, PARK2  -  parkinson prot...
# 1   [SYN1  -  synapsin i, PARK2  -  parkinson prot...
# 2   [SYN1  -  synapsin i, PARK2  -  parkinson prot...
# 3   [SYN1  -  synapsin i, PARK2  -  parkinson prot...
# 4   [PCDHA11  -  protocadherin alpha 11, PCDHA10  ...
# 5   [SYN1  -  synapsin i, PARK2  -  parkinson prot...
# 6   [SYN1  -  synapsin i, PARK2  -  parkinson prot...
# 7   [PCDHA11  -  protocadherin alpha 11, PCDHA10  ...
# 8   [SCN1A  -  sodium channel, voltage-gated, type...
# 9   [SYN1  -  synapsin i, PARK2  -  parkinson prot...
# 10  [PCDHA11  -  protocadherin alpha 11, PCDHA10  ...
# 11  [PCDHA11  -  protocadherin alpha 11, PCDHA10  ...
# 12  [PCDHA11  -  protocadherin alpha 11, PCDHA10  ...
# 13  [PARK2  -  parkinson protein 2, e3 ubiquitin p...
# 14  [SCN1A  -  sodium channel, voltage-gated, type...
# 15  [PARK2  -  parkinson protein 2, e3 ubiquitin p...
# 16  [SYN1  -  synapsin i, GRID2IP  -  glutamate re...
# 17  [SCN1A  -  sodium channel, voltage-gated, type...
# 18  [SYN1  -  synapsin i, GRID2IP  -  glutamate re...
# 19  [SCN1A  -  sodium channel, voltage-gated, type...
# 20  [SCN1A  -  sodium channel, voltage-gated, type...
# 21  [GRIK5  -  glutamate receptor, ionotropic, kai...
# 22  [PCDHA11  -  protocadherin alpha 11, PCDHA10  ...
# 23  [SCN1A  -  sodium channel, voltage-gated, type...
# 24  [OR2M4  -  olfactory receptor, family 2, subfa...
# 25  [SCN1A  -  sodium channel, voltage-gated, type...
# 26  [SCN1A  -  sodium channel, voltage-gated, type...
# 27  [SCN1A  -  sodium channel, voltage-gated, type...
# 28  [OR2M4  -  olfactory receptor, family 2, subfa...
# 29  [SCN1A  -  sodium channel, voltage-gated, type...
# 30  [PCDHA11  -  protocadherin alpha 11, PCDHA10  ...
# 31  [GRIK5  -  glutamate receptor, ionotropic, kai...
# 32  [AZGP1  -  alpha-2-glycoprotein 1, zinc-bindin...

# %%
# gene list / gene description column

gl0 = df0["Genes"].tolist()
gl1 = df1["Genes"].tolist()
gl2 = df2["Genes"].tolist()
gl3 = df3["Genes"].tolist()
gl4 = df4["Genes"].tolist()

# %%
print(gl2)
# Out:
# ['[SYN1  -  synapsin i, PARK2  -  parkinson protein 2, e3 ubiquitin protein ligase (parkin), SYN2  -  synapsin ii, DRD2  -  dopamine receptor d2, GLRA2  -  glycine receptor, alpha 2, CHRM3  -  cholinergic receptor, muscarinic 3, SLC12A5  -  solute carrier family 12 (potassium/chloride transporter), member 5, NRXN1  -  neurexin 1, HTR3A  -  5-hydroxytryptamine (serotonin) receptor 3a, ionotropic, SNAP25  -  synaptosomal-associated protein, 25kda, GABRG3  -  gamma-aminobutyric acid (gaba) a receptor, gamma 3, KCNQ2  -  potassium voltage-gated channel, kqt-like subfamily, member 2, KCNQ3  -  potassium voltage-gated channel, kqt-like subfamily, member 3, GRID2  -  glutamate receptor, ionotropic, delta 2, CNR1  -  cannabinoid receptor 1 (brain), GRID1  -  glutamate receptor, ionotropic, delta 1, NLGN1  -  neuroligin 1, UNC13A  -  unc-13 homolog a (c. elegans), GRIK5  -  glutamate receptor, ionotropic, kainate 5, GRIN1  -  glutamate receptor, ionotropic, n-methyl d-aspartate 1, GRIN2A  -  glutamate receptor, ionotropic, n-methyl d-aspartate 2a, GRIK2  -  glutamate receptor, ionotropic, kainate 2, GRIK3  -  glutamate receptor, ionotropic, kainate 3, NLGN4X  -  neuroligin 4, x-linked, CACNA1G  -  calcium channel, voltage-dependent, t type, alpha 1g subunit, CACNA1E  -  calcium channel, voltage-dependent, r type, alpha 1e subunit, GABRA4  -  gamma-aminobutyric acid (gaba) a receptor, alpha 4, GRM7  -  glutamate receptor, metabotropic 7, DLGAP2  -  discs, large (drosophila) homolog-associated protein 2, GABBR2  -  gamma-aminobutyric acid (gaba) b receptor, 2, DLGAP1  -  discs, large (drosophila) homolog-associated protein 1, ADORA2A  -  adenosine a2a receptor, CDH8  -  cadherin 8, type 2, PTCHD1  -  patched domain containing 1, HTR3C  -  5-hydroxytryptamine (serotonin) receptor 3c, ionotropic, IL1RAPL1  -  interleukin 1 receptor accessory protein-like 1, NLGN3  -  neuroligin 3]', '[SYN1  -  synapsin i, PARK2  -  parkinson protein 2, e3 ubiquitin protein ligase (parkin), SYN2  -  synapsin ii, DRD2  -  dopamine receptor d2, GLRA2  -  glycine receptor, alpha 2, CHRM3  -  cholinergic receptor, muscarinic 3, SLC12A5  -  solute carrier family 12 (potassium/chloride transporter), member 5, NRXN1  -  neurexin 1, HTR3A  -  5-hydroxytryptamine (serotonin) receptor 3a, ionotropic, SNAP25  -  synaptosomal-associated protein, 25kda, GABRG3  -  gamma-aminobutyric acid (gaba) a receptor, gamma 3, KCNQ2  -  potassium voltage-gated channel, kqt-like subfamily, member 2, KCNQ3  -  potassium voltage-gated channel, kqt-like subfamily, member 3, GRID2  -  glutamate receptor, ionotropic, delta 2, CNR1  -  cannabinoid receptor 1 (brain), GRID1  -  glutamate receptor, ionotropic, delta 1, NLGN1  -  neuroligin 1, UNC13A  -  unc-13 homolog a (c. elegans), GRIK5  -  glutamate receptor, ionotropic, kainate 5, GRIN1  -  glutamate receptor, ionotropic, n-methyl d-aspartate 1, GRIN2A  -  glutamate receptor, ionotropic, n-methyl d-aspartate 2a, GRIK2  -  glutamate receptor, ionotropic, kainate 2, GRIK3  -  glutamate receptor, ionotropic, kainate 3, NLGN4X  -  neuroligin 4, x-linked, CACNA1G  -  calcium channel, voltage-dependent, t type, alpha 1g subunit, CACNA1E  -  calcium channel, voltage-dependent, r type, alpha 1e subunit, GABRA4  -  gamma-aminobutyric acid (gaba) a receptor, alpha 4, GRM7  -  glutamate receptor, metabotropic 7, DLGAP2  -  discs, large (drosophila) homolog-associated protein 2, DLGAP1  -  discs, large (drosophila) homolog-associated protein 1, GABBR2  -  gamma-aminobutyric acid (gaba) b receptor, 2, ADORA2A  -  adenosine a2a receptor, PTCHD1  -  patched domain containing 1, CDH8  -  cadherin 8, type 2, HTR3C  -  5-hydroxytryptamine (serotonin) receptor 3c, ionotropic, IL1RAPL1  -  interleukin 1 receptor accessory protein-like 1, NLGN3  -  neuroligin 3]', '[SYN1  -  synapsin i, PARK2  -  parkinson protein 2, e3 ubiquitin protein ligase (parkin), SYN2  -  synapsin ii, DRD2  -  dopamine receptor d2, GLRA2  -  glycine receptor, alpha 2, CHRM3  -  cho ...

# %%
df_list = [df0, df1, df2, df3, df4]

gene_list = [gl0, gl1, gl2, gl3, gl4]

# %%
# number of genes in the enrichment GO terms

# iterate throuch each cell in the contingency table 
for enriched_cell in gene_list:
    
    # list to store extracted genes that belong to enriched GO terms
    enriched_genes = []
    
    # in a cell, iterate through enriched GO terms
    for go_term in enriched_cell:
        
        # need to remove confusing enclosing brackets from string 
        unparsed_string = go_term[1:-1]
        
        # then transform it into a list of unparsed gene + description strings
        unprocessed_list = unparsed_string.split('  -  ')
        
        # the first one can be added right away
        enriched_genes.append(unprocessed_list[0])
        
        # iterate through the list. last element ignored (it only contains a description)
        for gene_description in unprocessed_list[1:-1]:
            
            # the last word of the description contains a gene id (that belongs to the next description..)
            gene_id = gene_description.rsplit(' ', 1)[-1]
            enriched_genes.append(gene_id)
    
    print(len(set(enriched_genes)))
# Out:
# 60
# 137
# 143
# 75
# 93

# %%
# geometric average of p-values in GO terms enriched

# iterate throuch each cell in the contingency table 
for enriched_cell in df_list:
    print(np.round(stats.gmean(enriched_cell["P-value"].tolist()), 8))
# Out:
# 6.298e-05
# 5.077e-05
# 4.46e-06
# 0.00067657
# 3.845e-05

# %%
for enriched_cell in df_list:
    print(len(enriched_cell))
# Out:
# 35
# 58
# 33
# 2
# 59
